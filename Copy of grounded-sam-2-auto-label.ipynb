# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Use Grounded SAM 2 to Auto-Label Images
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/what-is-segment-anything-2/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/facebookresearch/segment-anything-2)
#
# On July 29th, 2024, Meta AI released Segment Anything 2 (SAM 2), a new image and video segmentation foundation model. With SAM 2, you can provide points in an image and generate a segmentation mask for the corresponding point. You can also provide points in a video and generate segmentation masks that are tracked across frames.
#
# SAM 2 follows on from the SAM model released by Meta earlier last year which has been used for tasks such as image segmentation in vision applications and as an image labeling assistant.  According to Meta, SAM 2 is 6x more accurate than the original SAM model at image segmentation tasks.
#
# Here is an example of SAM 2 segmenting parts of an image using points:
#
# ![](https://blog.roboflow.com/content/images/2024/07/Untitled-4.png)
#
# In this guide, we will show how to auto-label an image segmentation dataset using Grounded SAM 2, a combination of SAM 2 and a grounding model: Grounding DINO. With this combination, we can provide text prompts instead of coordinate prompts to auto-label objects.
#
# Without further ado, let's get started!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install dependencies
#
# First, we need to install the required dependencies for this project:

# %%
# !pip install git+https://github.com/autodistill/autodistill-grounded-sam-2 rf_groundingdino -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 60.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.9 MB/s eta 0:00:00
#   Building wheel for autodistill_grounded_sam_2 (setup.py) ... done
#   Building wheel for flash-attn (setup.py) ... done

# %% [markdown]
# ## Collect data
#
# For this project, we need a folder of unlabeled images. We will label these images with Grounded SAM 2, then use them to train a model.
#
# For this guide, we will use a dataset of shipping containers. We will use the dataset to train a model that can identify shipping containers.

# %%
#!wget https://media.roboflow.com/containers.zip
# !unzip /content/drive/MyDrive/PennFudanPed.zip
# Out:
# Archive:  /content/drive/MyDrive/PennFudanPed.zip
#    creating: PennFudanPed/train_images/
#   inflating: PennFudanPed/train_images/FudanPed00002.png
#   inflating: PennFudanPed/train_images/FudanPed00004.png
#   inflating: PennFudanPed/train_images/FudanPed00006.png
#   inflating: PennFudanPed/train_images/FudanPed00007.png
#   inflating: PennFudanPed/train_images/FudanPed00008.png
#   inflating: PennFudanPed/train_images/FudanPed00009.png
#   inflating: PennFudanPed/train_images/FudanPed00010.png
#   inflating: PennFudanPed/train_images/FudanPed00011.png
#   inflating: PennFudanPed/train_images/FudanPed00012.png
#   inflating: PennFudanPed/train_images/FudanPed00013.png
#   inflating: PennFudanPed/train_images/FudanPed00014.png
#   inflating: PennFudanPed/train_images/FudanPed00015.png
#   inflating: PennFudanPed/train_images/FudanPed00016.png
#   inflating: PennFudanPed/train_images/FudanPed00017.png
#   inflating: PennFudanPed/train_images/FudanPed00018.png
#   inflating: PennFudanPed/train_images/FudanPed00020.png
#   inflating: PennFudanPed/train_images/FudanPed00022.png
#   inflating: PennFudanPed/train_images/FudanPed00024.png
#   inflating: PennFudanPed/train_images/FudanPed00025.png
#   inflating: PennFudanPed/train_images/FudanPed00026.png
#   inflating: PennFudanPed/train_images/FudanPed00027.png
#   inflating: PennFudanPed/train_images/FudanPed00028.png
#   inflating: PennFudanPed/train_images/FudanPed00029.png
#   inflating: PennFudanPed/train_images/FudanPed00030.png
#   inflating: PennFudanPed/train_images/FudanPed00031.png
#   inflating: PennFudanPed/train_images/FudanPed00032.png
#   inflating: PennFudanPed/train_images/FudanPed00033.png
#   inflating: PennFudanPed/valid_images/PennPed00019.png
#   inflating: PennFudanPed/valid_images/PennPed00035.png
#   inflating: PennFudanPed/valid_images/PennPed00037.png
#   inflating: PennFudanPed/valid_images/PennPed00053.png
#   inflating: PennFudanPed/valid_images/PennPed00055.png
#   inflating: PennFudanPed/valid_images/PennPed00071.png
#   inflating: PennFudanPed/valid_images/PennPed00073.png
#   inflating: PennFudanPed/valid_images/PennPed00089.png
#   inflating: PennFudanPed/valid_images/PennPed00091.png
#    creating: PennFudanPed/valid_masks/
#   inflating: PennFudanPed/valid_masks/FudanPed00001_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00003_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00005_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00019_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00021_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00023_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00037_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00039_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00041_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00055_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00057_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00059_mask.png
#   inflating: PennFudanPed/valid_masks/FudanPed00073_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00001_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00017_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00019_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00035_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00037_mask.png
#  extracting: PennFudanPed/valid_masks/PennPed00053_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00055_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00071_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00073_mask.png
#  extracting: PennFudanPed/valid_masks/PennPed00089_mask.png
#   inflating: PennFudanPed/valid_masks/PennPed00091_mask.png

# %% [markdown]
# ## Load Grounded SAM 2
#
# With a dataset ready, we can load Grounded SAM 2.
#
# We need to provide an ontology for Grounded SAM 2. This refers to the objects that we want to identify, and the labels that we want to use in our dataset.
#
# An ontology uses the following structure:
#
# ```
# {"prompt": "label"}
# ```
#
# For example, the following ontology will send the prompt "shipping container" to a model and save the results with the label "container":
#
# ```
# {"shipping container": "container"}
# ```

# %%
from autodistill_grounded_sam_2 import GroundedSAM2
# Out:
# Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.

# %%
from autodistill.detection import CaptionOntology
from autodistill.utils import plot
import numpy as np
import cv2
import os
import random
import supervision as sv

# define an ontology to map class names to our Grounded SAM 2 prompt
# the ontology dictionary has the format {caption: class}
# where caption is the prompt sent to the base model, and class is the label that will
# be saved for that caption in the generated annotations
# then, load the model
base_model = GroundedSAM2(
    ontology=CaptionOntology(
        {
        "person": "person"
    }
    ),
    model = "Grounding DINO",
    grounding_dino_box_threshold=0.25
)
# Out:
# trying to load grounding dino directly
# downloading dino model weights
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
# final text_encoder_type: bert-base-uncased
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# ## Test the model
#
# Now that we have loaded the model, we can test it on images. Let's test on random images in the `containers` directory we downloaded earlier. If you are using your own dataset, replace the value of `IMAGE_DIR` with the folder where your unlabeled images are stored.

# %%
IMAGE_DIR = "/content/PennFudanPed/valid_images"
IMAGE_PATH = os.path.join(IMAGE_DIR, random.choice(os.listdir(IMAGE_DIR)))

results = base_model.predict(IMAGE_PATH).with_nms()
results = results[results.confidence > 0.3]

image = cv2.imread(IMAGE_PATH)

mask_annotator = sv.BoxAnnotator()

annotated_image = mask_annotator.annotate(
	image.copy(), detections=results
)

sv.plot_image(image=annotated_image, size=(8, 8))

# %% [markdown]
# If your prompt does not work well, update your ontology to use a new prompt.
#
# It may take a few tries to find a prompt that works.
#
# Note that Grounding DINO, on which Grounded SAM 2 depends for object identification, cannot identify all objects. If, after experimentation, you cannot get the model to identify objects of interest, this model may not be suited to your task.

# %% [markdown]
# ## Label the dataset
#
# Once you have found a prompt that works for your dataset, you can label your dataset like so:

# %%
base_model.label(IMAGE_DIR, extension="png")
# Out:
# Labeling /content/PennFudanPed/valid_images/FudanPed00039.png: 100%|██████████| 24/24 [00:23<00:00,  1.00it/s]
# Passing a `Dict[str, np.ndarray]` into `DetectionDataset` is deprecated and will be removed in `supervision-0.26.0`. Use a list of paths `List[str]` instead.
# Labeled dataset created - ready for distillation.

# %% [markdown]
# With a labeled dataset ready, the next step is to inspect the quality of the labels and train your model. Roboflow has utilities for both of these steps. With Roboflow, you can review and amend annotations, then use your dataset to train a model.
#
# [Create a free Roboflow account](https://roboflow.com), then create a new project in your Roboflow dashboard. Once you have a new project, you can upload your labeled data to the platform with the following code:

# %%
import roboflow

roboflow.login("owrx1LZjHtRJlYI9T1tP")

rf = roboflow.Roboflow()

workspace = rf.workspace("crowdcontrol")
workspace.upload_dataset(
    IMAGE_DIR + "_labeled/",
    "crowd-hnvl6",
    project_license="MIT",
    project_type="object-detection",
)
# Out:
# You are already logged into Roboflow. To make a different login,run roboflow.login(force=True).
# loading Roboflow workspace...
# loading Roboflow project...
# Uploading to existing project crowdcontrol/crowd-hnvl6
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00005.jpg (EDToob1a1b6UHgHUsYhQ) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00037.jpg (HhwMQSVqWylIuuSPy7lu) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00019.jpg (sCWod1A6CMGdXsq6ysDj) [0.7s] / annotations = OK [0.7s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00023.jpg (o0238fQeCb8pyXOjgdyA) [0.7s] / annotations = OK [0.7s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00073.jpg (9OsQq1IB8XLMgnZfWfw5) [0.9s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00039.jpg (Gh2cKNiuZjQu8XEFQQaJ) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00041.jpg (vrRXSYn3u3IrKbTQ5Eqm) [1.0s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00001.jpg (rMNsMBMrn8UlobX0j49a) [1.1s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00021.jpg (OtNnpmYqAxpOHb671VRb) [1.1s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/FudanPed00057.jpg (oJQ5olcUNaeusNpyJiOB) [1.2s] / annotations = OK [0.8s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00001.jpg (Gto1LrHZL9VT59nan7je) [1.0s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00055.jpg (vQLoavaa9ZwHJWtUU6BF) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00035.jpg (skPYXf5IisAsxHbJ3GI9) [0.7s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00037.jpg (0kRuEHoewJ52s4E82zeV) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00089.jpg (BZBO9yQQKaA3qHk84GlJ) [0.7s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00073.jpg (Yh1QS0bkyuYbVwFweJn6) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00091.jpg (5DdXX4fFdrC53OsnV7q3) [0.8s] / annotations = OK [0.4s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00071.jpg (Vk8OWyrGy2SPqogNNUPj) [1.1s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/train/images/PennPed00017.jpg (5u80CN9UIuToUiVbHVMp) [1.4s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/valid/images/FudanPed00003.jpg (DzaZ2lKH2KQTxSewe18R) [1.0s] / annotations = OK [0.4s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/valid/images/PennPed00053.jpg (sVAOMSUJqw7gxjnqonqT) [0.5s] / annotations = OK [0.6s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/valid/images/PennPed00019.jpg (ZXXE9p5sxSOK9LVmUgZ5) [0.6s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/valid/images/FudanPed00055.jpg (FYaLCpbVvXmDUwjkjqs3) [0.8s] / annotations = OK [0.5s]
# [UPLOADED] /content/PennFudanPed/valid_images_labeled/valid/images/FudanPed00059.jpg (pIbUQWiXPB6BPys0ivcR) [0.8s] / annotations = OK [0.5s]

# %% [markdown]
# Above, replace:
#
# - `WORKSPACE_ID` with your workspace ID. [Learn how to find your workspace ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids)
# - `PROJECT_ID` with the name of your project ID. [Learn how to find your project ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids)
#
# Once you have run the code cell above, go back to your Roboflow project. Here, you can inspect the quality of all annotations and make the requisite changes
#
# You can add, adjust, and remove polygons. To learn more about annotating with Roboflow and the features available, refer to the [Roboflow Annotate documentation](https://docs.roboflow.com/annotate/annotation-tools).

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
